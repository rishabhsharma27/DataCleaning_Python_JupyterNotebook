# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("E:\Git_repo\ComputerStoreDataset\dirty_data.csv")
df2 = pd.read_csv("E:\Git_repo\ComputerStoreDataset\missing_data.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:2: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:2: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\risha\AppData\Local\Temp\ipykernel_16424\3203029369.py:1: SyntaxWarning: invalid escape sequence '\G'
#   df1 = pd.read_csv("E:\Git_repo\ComputerStoreDataset\dirty_data.csv")
# C:\Users\risha\AppData\Local\Temp\ipykernel_16424\3203029369.py:2: SyntaxWarning: invalid escape sequence '\G'
#   df2 = pd.read_csv("E:\Git_repo\ComputerStoreDataset\missing_data.csv")

# %%
df1.describe()
# Out:
#          order_price  delivery_charges  customer_lat  customer_long  \
# count     500.000000        500.000000    500.000000     500.000000
# mean    25522.216000         76.658200    -35.835234     144.969494
# std     86333.729169         14.481465     12.045393       0.022720
# min       585.000000         46.350000    -37.827123     144.924967
# 25%      7050.000000         65.982500    -37.818222     144.953488
# 50%     12807.500000         76.310000    -37.812165     144.965357
# 75%     20360.000000         82.555000    -37.805364     144.983985
# max    947691.000000        114.040000     37.826339     145.019837
#
#        coupon_discount   order_total  distance_to_nearest_warehouse
# count       500.000000  5.000000e+02                     500.000000
# mean         10.890000  3.920967e+04                       2.204224
# std           8.649134  2.741940e+05                       8.812416
# min           0.000000  6.392900e+02                       0.107800
# ...

# %%
df1.head()
# Out:
#     order_id   customer_id        date nearest_warehouse  \
# 0  ORD182494  ID6197211592  2019-06-22          Thompson
# 1  ORD395518  ID0282825849  2019-12-29          Thompson
# 2  ORD494479  ID0579391891  2019-03-02         Nickolson
# 3  ORD019224  ID4544561904  2019-01-12         Nickolson
# 4  ORD104032  ID6231506320  2019-11-28         Nickolson
#
#                                        shopping_cart  order_price  \
# 0  [('Lucent 330S', 1), ('Thunder line', 2), ('iS...        12200
# 1        [('Thunder line', 1), ('Universe Note', 2)]         9080
# 2               [('Thunder line', 1), ('pearTV', 2)]        10670
# 3  [('Universe Note', 1), ('Alcon 10', 2), ('Oliv...        24800
# 4  [('Universe Note', 1), ('Olivia x460', 1), ('i...         9145
#
#    delivery_charges  customer_lat  customer_long  coupon_discount  \
# 0             79.89    -37.815105     144.932843               10
# 1             62.71    -37.802736     144.951118                0
# ...

# %%
df1.columns
# Out:
# Index(['order_id', 'customer_id', 'date', 'nearest_warehouse', 'shopping_cart',
#        'order_price', 'delivery_charges', 'customer_lat', 'customer_long',
#        'coupon_discount', 'order_total', 'season', 'is_expedited_delivery',
#        'distance_to_nearest_warehouse', 'latest_customer_review',
#        'is_happy_customer'],
#       dtype='object')

# %%
df1.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# date                             0
# nearest_warehouse                0
# shopping_cart                    0
# order_price                      0
# delivery_charges                 0
# customer_lat                     0
# customer_long                    0
# coupon_discount                  0
# order_total                      0
# season                           0
# is_expedited_delivery            0
# distance_to_nearest_warehouse    0
# latest_customer_review           1
# is_happy_customer                0
# dtype: int64

# %%
df1['order_price'].describe()
# Out:
# count       500.000000
# mean      25522.216000
# std       86333.729169
# min         585.000000
# 25%        7050.000000
# 50%       12807.500000
# 75%       20360.000000
# max      947691.000000
# Name: order_price, dtype: float64

# %%
df1['shopping_cart']
# Out:
# 0      [('Lucent 330S', 1), ('Thunder line', 2), ('iS...
# 1            [('Thunder line', 1), ('Universe Note', 2)]
# 2                   [('Thunder line', 1), ('pearTV', 2)]
# 3      [('Universe Note', 1), ('Alcon 10', 2), ('Oliv...
# 4      [('Universe Note', 1), ('Olivia x460', 1), ('i...
#                              ...
# 495               [('Alcon 10', 2), ('iAssist Line', 2)]
# 496    [('pearTV', 2), ('Candle Inferno', 2), ('Toshi...
# 497    [('pearTV', 1), ('Alcon 10', 1), ('Lucent 330S...
# 498    [('iStream', 1), ('Candle Inferno', 1), ('iAss...
# 499    [('iStream', 1), ('Toshika 750', 1), ('Alcon 1...
# Name: shopping_cart, Length: 500, dtype: object

# %%
df1['c'] = df['shopping_cart'].str.replace("('", "{\"items\": ")

# %%
df.head()
# Out:
#     order_id   customer_id        date nearest_warehouse  \
# 0  ORD182494  ID6197211592  2019-06-22          Thompson
# 1  ORD395518  ID0282825849  2019-12-29          Thompson
# 2  ORD494479  ID0579391891  2019-03-02         Nickolson
# 3  ORD019224  ID4544561904  2019-01-12         Nickolson
# 4  ORD104032  ID6231506320  2019-11-28         Nickolson
#
#                                        shopping_cart  order_price  \
# 0  [('Lucent 330S', 1), ('Thunder line', 2), ('iS...        12200
# 1        [('Thunder line', 1), ('Universe Note', 2)]         9080
# 2               [('Thunder line', 1), ('pearTV', 2)]        10670
# 3  [('Universe Note', 1), ('Alcon 10', 2), ('Oliv...        24800
# 4  [('Universe Note', 1), ('Olivia x460', 1), ('i...         9145
#
#    delivery_charges  customer_lat  customer_long  coupon_discount  \
# 0             79.89    -37.815105     144.932843               10
# 1             62.71    -37.802736     144.951118                0
# ...

# %%
#merged = pd.merge(df1, df2, on='order_id', how='outer')

# %%
import os

# %%
files = os.listdir('E:/Git_repo/ComputerStoreDataset')

# %%
print(files)
# Out:
# ['dirty_data.csv', 'missing_data.csv', 'warehouses.csv']

# %%
df_concat = pd.DataFrame()

for file in files:
    if ((file[0] == 'm') | (file[0] == 'd')):
         df = pd.read_csv('E:/Git_repo/ComputerStoreDataset/'+file)
         df_concat = pd.concat([df_concat, df])

# %%
df_concat.shape
# Out:
# (1000, 16)

# %%
df_concat.sample(20)
# Out:
#       order_id   customer_id        date nearest_warehouse  \
# 29   ORD406814  ID0452381262  2019-03-01          Thompson
# 403  ORD363836  ID0746922230  2019-06-29         Nickolson
# 75   ORD070810  ID0317369540  2019-02-22          Thompson
# 302  ORD151900  ID0576873448  2019-02-10            Bakers
# 223  ORD119688  ID4061053480  2019-12-08            Bakers
# 264  ORD374251  ID0702363476  2019-03-03          Thompson
# 22   ORD277791  ID5299391822  2019-07-26          Thompson
# 40   ORD466433  ID3218293544  2019-03-08          Thompson
# 286  ORD004848  ID0589421007  2019-05-15         Nickolson
# 128  ORD471978  ID6197211588  2019-03-13          Thompson
# 410  ORD122150  ID0248746924  2019-01-20            Bakers
# 304  ORD267476  ID4716795474  2019-09-10          Thompson
# 422  ORD148182  ID0591435914  2019-10-18         Nickolson
# 212  ORD232552  ID0591258186  2019-05-27          Thompson
# 27   ORD126262  ID1495248920  2019-08-19         Nickolson
# ...

# %%
df_concat.dtypes
# Out:
# order_id                          object
# customer_id                       object
# date                              object
# nearest_warehouse                 object
# shopping_cart                     object
# order_price                      float64
# delivery_charges                 float64
# customer_lat                     float64
# customer_long                    float64
# coupon_discount                    int64
# order_total                      float64
# season                            object
# is_expedited_delivery               bool
# distance_to_nearest_warehouse    float64
# latest_customer_review            object
# is_happy_customer                 object
# dtype: object

# %%
df['shopping_cart'] = (
    df['shopping_cart']
      .str.replace('(', '{')
      .str.replace(')', '}')
      .str.replace("'", " ")
)

# %%
df.loc['order_id']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 df.loc['order_id']
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexing.py:1381, in _LocIndexer._get_label(self, label, axis)
# ...

# %%
df[['order_id','date']].sort_values('order_id')
# Out:
#       order_id        date
# 38   ORD000459  2019-12-17
# 362  ORD003106  2019-08-18
# 61   ORD004228  2019-10-12
# 95   ORD004262  2019-06-23
# 5    ORD005004  2019-05-07
# ..         ...         ...
# 238  ORD495321  2019-05-02
# 321  ORD496151  2019-12-23
# 130  ORD498065  2019-11-17
# 206  ORD498344  2019-08-24
# 168  ORD498853  2019-08-17
#
# [500 rows x 2 columns]

# %%
df.query(
    "order_id.str.contains('2112')")
# Out:
#     order_id   customer_id        date nearest_warehouse  \
# 0  ORD382112  ID0289597187  2019-03-06          Thompson
#
#                             shopping_cart  order_price  delivery_charges  \
# 0  [{ pearTV , 1}, { Candle Inferno , 2}]       7170.0             61.72
#
#    customer_lat  customer_long  coupon_discount  order_total  season  \
# 0    -37.811782     144.951972               15      6156.22  Autumn
#
#    is_expedited_delivery  distance_to_nearest_warehouse  \
# 0                   True                         0.4425
#
#                               latest_customer_review is_happy_customer
# 0  to many adds in ui it has adds, sends info to ...             False
